# %%
from pathlib import Path
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [20, 10]

# %%
import torch
import numpy as np

# %%
import a4_course_cvdl_t2

# %%
from a4_course_cvdl_t2.impl.train import train
from a4_course_cvdl_t2.impl.data import CocoTextDetection, CocoDetectionPrepareTransform

# %% [markdown]
# ## Подготовка. Игрушечный датасет: TINY COCO
# Разметка COCO для 16 изображений
#
# https://github.com/chongruo/tiny-coco

# %%
import a4_course_cvdl_t2
TINY_COCO_BASE = Path(a4_course_cvdl_t2.__file__).parent.parent / 'data'
TINY_COCO_BASE.exists()
# Out:
# True

# %%
from torchvision.datasets import CocoDetection

# %% [markdown]
# Если CocoDetection падает, вероятно, вам нужно установить pycocotools: `pip install pycocotools`
#
# Раньше pycocotools требовал предварительную установки cython:
# `pip install cython`
# Раньше установка на windows работала криво: https://stackoverflow.com/questions/52920222/could-not-install-pycocotools-in-windows-fatal-error-c1083-cannot-open-include
#
# На новых версиях python на windows теперь работает ок.

# %%
pip install pycocotools
# Out:
# Collecting pycocotools
#   Downloading pycocotools-2.0.7-cp310-cp310-macosx_10_9_universal2.whl.metadata (1.1 kB)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/site-packages (from pycocotools) (3.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/site-packages (from pycocotools) (1.23.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)
# Downloading pycocotools-2.0.7-cp310-cp310-macosx_10_9_universal2.whl (169 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.1/169.1 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pycocotools
# Successfully installed pycocotools-2.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
def draw_boxes(image_np, yc_t, xc_t, hy_t, wx_t, color=(0, 255, 0), thick=1):
    img = np.array(image_np)
    num_boxes = len(yc_t)
    val = np.array(color)
    for idx in range(num_boxes):
        yc = yc_t[idx]
        xc = xc_t[idx]
        hy = hy_t[idx]
        wx = wx_t[idx]
        img[
                yc - hy//2 - thick : yc - hy//2 + thick, 
                xc - wx//2 : xc + wx//2, 
        ] = val
        img[
                yc + hy//2 - thick : yc + hy//2 + thick, 
                xc - wx//2 : xc + wx//2, 
        ] = val

        img[
                yc - hy//2 : yc + hy//2, 
                (xc - wx//2 - thick): (xc - wx//2 + thick), 
        ] = val
        img[
                yc - hy//2 : yc + hy//2, 
                xc + wx//2 - thick: xc + wx//2 + thick, 
        ] = val
    return img

# %%
# без transform датасет возвращает изображения и dict
ds = CocoDetection(
    TINY_COCO_BASE / 'train_2017_small',
    TINY_COCO_BASE / 'instances_train2017_small.json',
)
x, y = ds[1]
print("-------")
print(f"Tiny coco size: {len(ds)}")
print(f"Детекций на изображении: {len(y)}")
x
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# -------
# Tiny coco size: 16
# Детекций на изображении: 7
# <PIL.Image.Image image mode=RGB size=640x427>

# %%
# с transform - тензоры размера size и отмасштабированные детекции
# размер тензора детекций всегда одинаковый (100 по умолчанию), "нехватающие" детекции
# заполняются числом 0.

ds = CocoDetection(
    TINY_COCO_BASE / 'train_2017_small',
    TINY_COCO_BASE / 'instances_train2017_small.json',
    transforms=CocoDetectionPrepareTransform(size=(256, 256))
)
img_t, det_t = ds[1]
print("-------")
print(f"Тип изображения:{type(img_t)}")
print(f"Форма детекций: {det_t.shape}")
print(f"Тензор детекций[10 из 100]:\n{det_t[:10, :]}")
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# -------
# Тип изображения:<class 'torch.Tensor'>
# Форма детекций: torch.Size([100, 6])
# Тензор детекций[10 из 100]:
# tensor([[127.1367,  69.8900, 251.9831, 138.2520,   1.0000,   1.0000],
#         [ 98.6739, 172.1500, 194.7458, 117.5960,   1.0000,   1.0000],
#         [102.3011, 189.5560,  51.5178,  49.6160,  50.0000,   1.0000],
#         [176.7209, 191.3820,  69.1919,  51.9320,  51.0000,   1.0000],
#         [ 73.4067, 240.1340, 103.8269,  31.7320,  46.0000,   1.0000],
#         [159.7842, 196.6280, 192.4317, 118.7440,  67.0000,   1.0000],
#         [ 14.8654, 218.2620,  29.0593,  60.0600,   1.0000,   1.0000],
#         [  0.0000,   0.0000,   0.0000,   0.0000,   0.0000,   0.0000],
#         [  0.0000,   0.0000,   0.0000,   0.0000,   0.0000,   0.0000],
#         [  0.0000,   0.0000,   0.0000,   0.0000,   0.0000,   0.0000]])

# %%
_j = 0

img_n = img_t.permute(1, 2, 0).numpy()
det_n = np.round(det_t.numpy()).astype(np.uint8)
# отрисовать одну детекцию
#det_n = det_n[_j:_j+1,]

plt.imshow(draw_boxes(
    img_t.permute(1, 2, 0).numpy(), det_n[:, 0], det_n[:, 1], det_n[:, 2], det_n[:, 3] 
))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Запуск отдельных компонентов

# %%
img_t, det_t = ds[1]
x = img_t[None]
y = det_t[None]

# %% [markdown]
# Стандартный resnet34 понижает в 32 раза размерность h, w и возвращает c=512 каналов

# %%
from a4_course_cvdl_t2.backbone import HeadlessPretrainedResnet18Encoder

pre_resnet = HeadlessPretrainedResnet18Encoder()
x1 = pre_resnet(x)
print(x.shape)
# Out:
# /usr/local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# torch.Size([1, 3, 256, 256])

# %% [markdown]
# Ваш resnet18 должен возвращать такой же тензор

# %%
from a4_course_cvdl_t2.backbone import HeadlessResnet18Encoder
x = img_t[None]
resnet = HeadlessResnet18Encoder()
x2 = resnet(x)
(x1.shape == x2.shape)
# Out:
# True

# %% [markdown]
# Слой UpscaleTwiceLayer повышает в 2 раза h и w

# %%
from a4_course_cvdl_t2.backbone import UpscaleTwiceLayer
assert x2.shape == (1, 512, 8, 8), "x2 должен быть получен из resnet!"
up1 = UpscaleTwiceLayer(512, 64)
x3 = up1(x2)
assert x3.shape == (1, 64, 16, 16), x3.shape

# %% [markdown]
# Бэкбон объединяет энкодер и слои апскейл

# %%
from a4_course_cvdl_t2.backbone import ResnetBackbone

backbone = ResnetBackbone()
x4 = backbone(x)

assert x4.shape == (1, 64, 64, 64)

# %% [markdown]
# Голова возвращает тензора c class_probs, offsets и sizes

# %%
from a4_course_cvdl_t2.head import CenterNetHead
c_classes = 70
head = CenterNetHead(k_in_channels=64, c_classes=c_classes)
x5 = head(x4)
assert x5.shape == (1, c_classes + 4, 64, 64)
class_heatmap, size_heatmap, offsets_heatmap = torch.split(x5, [c_classes, 2, 2], dim=1)
assert class_heatmap.shape == (1, c_classes, 64, 64)
assert size_heatmap.shape == (1, 2, 64, 64)
assert offsets_heatmap.shape == (1, 2, 64, 64)

# %% [markdown]
# Конвертация представления боксов.
#
# ObjectsToPoints

# %%
from a4_course_cvdl_t2.convert import ObjectsToPoints

objects_to_points = ObjectsToPoints(hw=256, num_classes=70, smooth_kernel_size=9)

# %%
y.shape
# Out:
# torch.Size([1, 100, 6])

# %%
y_points = objects_to_points(y)

# %%
plt.imshow(y_points[0, :-4].sum(axis=0))
plt.colorbar()

# %%
img_example = x[0].permute(1, 2, 0).numpy()
img_example[:, :, 1] += y_points[0, :-4].sum(axis=0).numpy()
plt.imshow(img_example)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Проверка лосса

# %%
from a4_course_cvdl_t2.loss import CenterNetLoss
objects_to_points = ObjectsToPoints(hw=64, num_classes=70, smooth_kernel_size=3)
loss = CenterNetLoss(obj_to_points=objects_to_points)

# %%
loss(x5, y).flatten()
# Out:
# tensor([6.3565e+03, 4.5128e-01, 4.5562e+00], grad_fn=<ViewBackward0>)

# %% [markdown]
# ## Запуск тренировки на TinyCoco

# %%
# Для теста оставим из всех классов COCO (https://huggingface.co/spaces/CVPR/WALT/blob/main/mmdet/datasets/coco.py#L23)
# только один:
# -- person(1) -> 0 класс (человек)
# Остальные уберем

ids_map = {1: 0}

ds = CocoDetection(
    TINY_COCO_BASE / 'train_2017_small',
    TINY_COCO_BASE / 'instances_train2017_small.json',
    transforms=CocoDetectionPrepareTransform(size=(256,256), ids_map=ids_map) #ids_map отображает номера классов c TinyCoco в 0 
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %%
x, y = ds[1]
y[:10]
# Out:
# tensor([[127.1367,  69.8900, 251.9831, 138.2520,   0.0000,   1.0000],
#         [ 98.6739, 172.1500, 194.7458, 117.5960,   0.0000,   1.0000],
#         [ 14.8654, 218.2620,  29.0593,  60.0600,   0.0000,   1.0000],
#         [  0.0000,   0.0000,   0.0000,   0.0000,   0.0000,   0.0000],
#         [  0.0000,   0.0000,   0.0000,   0.0000,   0.0000,   0.0000],
#         [  0.0000,   0.0000,   0.0000,   0.0000,   0.0000,   0.0000],
#         [  0.0000,   0.0000,   0.0000,   0.0000,   0.0000,   0.0000],
#         [  0.0000,   0.0000,   0.0000,   0.0000,   0.0000,   0.0000],
#         [  0.0000,   0.0000,   0.0000,   0.0000,   0.0000,   0.0000],
#         [  0.0000,   0.0000,   0.0000,   0.0000,   0.0000,   0.0000]])

# %%
from a4_course_cvdl_t2.network import CenterNet

net = CenterNet(head_kwargs={'c_classes': 1}, nms_kwargs={'kernel_size': 5})
crit = CenterNetLoss(obj_to_points=ObjectsToPoints(num_classes=1))

# %%
net = train(ds, net=net, criterion=crit, batch_size=16, epochs=100, lr=1e-3)
# Out:
# epoch 0|0; total loss:4407.40673828125
# last losses: [4404.8232421875, 0.2098621129989624, 2.373326539993286]
# epoch 1|0; total loss:1326.5179443359375
# last losses: [1323.97216796875, 0.19957339763641357, 2.346158027648926]
# epoch 2|0; total loss:358.99859619140625
# last losses: [356.49896240234375, 0.1888936161994934, 2.310728073120117]
# epoch 3|0; total loss:121.82636260986328
# last losses: [119.3603744506836, 0.18078424036502838, 2.2852039337158203]
# epoch 4|0; total loss:66.91232299804688
# last losses: [64.48379516601562, 0.1731797605752945, 2.255347490310669]
# epoch 5|0; total loss:56.46076965332031
# last losses: [54.07032775878906, 0.16548651456832886, 2.224954605102539]
# epoch 6|0; total loss:56.48676300048828
# last losses: [54.130470275878906, 0.16075202822685242, 2.1955413818359375]
# epoch 7|0; total loss:58.80341720581055
# last losses: [56.48094177246094, 0.1554061472415924, 2.167067527770996]
# epoch 8|0; total loss:61.12929153442383
# last losses: [58.839813232421875, 0.14952538907527924, 2.139954090118408]
# epoch 9|0; total loss:62.831153869628906
# last losses: [60.57109069824219, 0.14521479606628418, 2.1148505210876465]
# epoch 10|0; total loss:63.69609832763672
# last losses: [61.460350036621094, 0.14328323304653168, 2.0924646854400635]
# epoch 11|0; total loss:63.70326232910156
# last losses: [61.4881477355957, 0.14102286100387573, 2.0740926265716553]
# epoch 12|0; total loss:62.924461364746094
# last losses: [60.72725296020508, 0.13829389214515686, 2.0589137077331543]
# epoch 13|0; total loss:61.49787139892578
# last losses: [59.314109802246094, 0.13708001375198364, 2.046682119369507]
# epoch 14|0; total loss:59.52864074707031
# last losses: [57.354583740234375, 0.1365479826927185, 2.037511110305786]
# epoch 15|0; total loss:57.05388641357422
# last losses: [54.88589096069336, 0.13630367815494537, 2.031691312789917]
# epoch 16|0; total loss:54.13751220703125
# last losses: [51.97113037109375, 0.13677379488945007, 2.029611110687256]
# epoch 17|0; total loss:51.01509094238281
# last losses: [48.846412658691406, 0.13781028985977173, 2.0308666229248047]
# epoch 18|0; total loss:47.85456466674805
# last losses: [45.680091857910156, 0.13958126306533813, 2.0348947048187256]
# epoch 19|0; total loss:44.88766098022461
# last losses: [42.705589294433594, 0.14126795530319214, 2.0408031940460205]
# epoch 20|0; total loss:42.28593063354492
# last losses: [40.09463882446289, 0.14300893247127533, 2.0482821464538574]
# epoch 21|0; total loss:40.23640060424805
# last losses: [38.03474426269531, 0.14487725496292114, 2.056779384613037]
# epoch 22|0; total loss:38.90675354003906
# last losses: [36.69473648071289, 0.14673280715942383, 2.0652847290039062]
# epoch 23|0; total loss:38.222164154052734
# last losses: [36.001121520996094, 0.14842310547828674, 2.0726211071014404]
# epoch 24|0; total loss:37.819766998291016
# last losses: [35.5924072265625, 0.14971135556697845, 2.0776467323303223]
# epoch 25|0; total loss:37.12430191040039
# last losses: [34.89604568481445, 0.1500035971403122, 2.0782511234283447]
# epoch 26|0; total loss:35.84967803955078
# last losses: [33.630821228027344, 0.1483260691165924, 2.070528507232666]
# epoch 27|0; total loss:34.581634521484375
# last losses: [32.3868293762207, 0.1453673392534256, 2.0494384765625]
# epoch 28|0; total loss:33.340545654296875
# last losses: [31.16651725769043, 0.14262261986732483, 2.0314083099365234]
# epoch 29|0; total loss:31.820451736450195
# last losses: [29.647075653076172, 0.14158517122268677, 2.0317914485931396]
# epoch 30|0; total loss:30.96391487121582
# last losses: [28.7970027923584, 0.14265984296798706, 2.024251699447632]
# epoch 31|0; total loss:29.96117401123047
# last losses: [27.801773071289062, 0.14162343740463257, 2.017777681350708]
# epoch 32|0; total loss:28.75829315185547
# last losses: [26.606386184692383, 0.1404639184474945, 2.0114431381225586]
# epoch 33|0; total loss:27.835975646972656
# last losses: [25.69152069091797, 0.1391821801662445, 2.005272626876831]
# epoch 34|0; total loss:26.987154006958008
# last losses: [24.839550018310547, 0.1390964537858963, 2.008507490158081]
# epoch 35|0; total loss:26.321823120117188
# last losses: [24.1705379486084, 0.1392185539007187, 2.0120649337768555]
# epoch 36|0; total loss:25.5203914642334
# last losses: [23.36817169189453, 0.13940763473510742, 2.0128121376037598]
# epoch 37|0; total loss:24.796871185302734
# last losses: [22.648502349853516, 0.1384928822517395, 2.0098772048950195]
# epoch 38|0; total loss:24.1331787109375
# last losses: [21.985729217529297, 0.13852296769618988, 2.008925437927246]
# epoch 39|0; total loss:23.478260040283203
# last losses: [21.32976531982422, 0.1376727819442749, 2.0108232498168945]
# epoch 40|0; total loss:22.913551330566406
# last losses: [20.76201629638672, 0.13787904381752014, 2.0136568546295166]
# epoch 41|0; total loss:22.305360794067383
# last losses: [20.16312599182129, 0.1366361528635025, 2.0055975914001465]
# epoch 42|0; total loss:21.988245010375977
# last losses: [19.838171005249023, 0.1375894844532013, 2.0124831199645996]
# epoch 43|0; total loss:21.07436752319336
# last losses: [18.92388916015625, 0.13763435184955597, 2.0128438472747803]
# epoch 44|0; total loss:20.915512084960938
# last losses: [18.784576416015625, 0.1366460919380188, 1.9942890405654907]
# epoch 45|0; total loss:20.899141311645508
# last losses: [18.76152992248535, 0.13890738785266876, 1.9987046718597412]
# epoch 46|0; total loss:20.54067039489746
# last losses: [18.386690139770508, 0.13812443614006042, 2.0158557891845703]
# epoch 47|0; total loss:19.06674575805664
# last losses: [16.911901473999023, 0.1376255303621292, 2.017219066619873]
# epoch 48|0; total loss:19.449262619018555
# last losses: [17.3162841796875, 0.1361583173274994, 1.9968208074569702]
# epoch 49|0; total loss:18.065052032470703
# last losses: [15.924280166625977, 0.13767985999584198, 2.0030927658081055]
# epoch 50|0; total loss:17.821884155273438
# last losses: [15.66055679321289, 0.13872751593589783, 2.0226004123687744]
# epoch 51|0; total loss:17.61675262451172
# last losses: [15.460756301879883, 0.13869793713092804, 2.0172982215881348]
# epoch 52|0; total loss:16.93050765991211
# last losses: [14.780834197998047, 0.1376294195652008, 2.0120432376861572]
# epoch 53|0; total loss:16.671546936035156
# last losses: [14.534666061401367, 0.13869215548038483, 1.9981889724731445]
# epoch 54|0; total loss:16.320955276489258
# last losses: [14.173879623413086, 0.13656318187713623, 2.0105130672454834]
# epoch 55|0; total loss:15.859522819519043
# last losses: [13.706954956054688, 0.13600318133831024, 2.0165646076202393]
# epoch 56|0; total loss:15.55286979675293
# last losses: [13.392501831054688, 0.13784119486808777, 2.022526741027832]
# epoch 57|0; total loss:15.304407119750977
# last losses: [13.147192001342773, 0.1392192542552948, 2.017995595932007]
# epoch 58|0; total loss:14.927057266235352
# last losses: [12.779485702514648, 0.13923189043998718, 2.008340358734131]
# epoch 59|0; total loss:14.555351257324219
# last losses: [12.403087615966797, 0.13704952597618103, 2.015213966369629]
# epoch 60|0; total loss:14.260285377502441
# last losses: [12.096125602722168, 0.1374334692955017, 2.026726484298706]
# epoch 61|0; total loss:14.03264045715332
# last losses: [11.86159896850586, 0.13861118257045746, 2.03243088722229]
# epoch 62|0; total loss:13.756834030151367
# last losses: [11.586097717285156, 0.13928885757923126, 2.031447172164917]
# epoch 63|0; total loss:13.517568588256836
# last losses: [11.35203742980957, 0.13952119648456573, 2.0260095596313477]
# epoch 64|0; total loss:13.306904792785645
# last losses: [11.140422821044922, 0.13998562097549438, 2.026496171951294]
# epoch 65|0; total loss:13.052288055419922
# last losses: [10.87496280670166, 0.13991305232048035, 2.037412405014038]
# epoch 66|0; total loss:12.843658447265625
# last losses: [10.658875465393066, 0.1402866244316101, 2.044496774673462]
# epoch 67|0; total loss:12.618518829345703
# last losses: [10.436455726623535, 0.1394040435552597, 2.042659044265747]
# epoch 68|0; total loss:12.429695129394531
# last losses: [10.25606918334961, 0.13821277022361755, 2.035412311553955]
# epoch 69|0; total loss:12.238931655883789
# last losses: [10.066793441772461, 0.1381027102470398, 2.0340359210968018]
# epoch 70|0; total loss:12.074691772460938
# last losses: [9.894174575805664, 0.13940152525901794, 2.0411155223846436]
# epoch 71|0; total loss:11.913431167602539
# last losses: [9.719877243041992, 0.14045600593090057, 2.053097724914551]
# epoch 72|0; total loss:11.748990058898926
# last losses: [9.552427291870117, 0.14049877226352692, 2.0560638904571533]
# epoch 73|0; total loss:11.604523658752441
# last losses: [9.41667652130127, 0.13927540183067322, 2.0485715866088867]
# epoch 74|0; total loss:11.457281112670898
# last losses: [9.272726058959961, 0.1394340991973877, 2.045121669769287]
# epoch 75|0; total loss:11.324674606323242
# last losses: [9.133333206176758, 0.14032390713691711, 2.0510172843933105]
# epoch 76|0; total loss:11.199560165405273
# last losses: [9.002148628234863, 0.14043891429901123, 2.0569722652435303]
# epoch 77|0; total loss:11.07681941986084
# last losses: [8.882850646972656, 0.13882394134998322, 2.055145263671875]
# epoch 78|0; total loss:10.95417594909668
# last losses: [8.765443801879883, 0.13777776062488556, 2.0509543418884277]
# epoch 79|0; total loss:10.8408784866333
# last losses: [8.652512550354004, 0.13815774023532867, 2.0502078533172607]
# epoch 80|0; total loss:10.729607582092285
# last losses: [8.535839080810547, 0.1385103166103363, 2.055257797241211]
# epoch 81|0; total loss:10.62903118133545
# last losses: [8.429060935974121, 0.13822415471076965, 2.0617458820343018]
# epoch 82|0; total loss:10.532533645629883
# last losses: [8.331920623779297, 0.13761499524116516, 2.062998056411743]
# epoch 83|0; total loss:10.427774429321289
# last losses: [8.228902816772461, 0.13768722116947174, 2.0611844062805176]
# epoch 84|0; total loss:10.331418991088867
# last losses: [8.135092735290527, 0.1371036320924759, 2.0592217445373535]
# epoch 85|0; total loss:10.235475540161133
# last losses: [8.036986351013184, 0.13673637807369232, 2.0617527961730957]
# epoch 86|0; total loss:10.14754867553711
# last losses: [7.947389125823975, 0.13612863421440125, 2.064030408859253]
# epoch 87|0; total loss:10.064257621765137
# last losses: [7.866270542144775, 0.135440394282341, 2.062546491622925]
# epoch 88|0; total loss:9.978843688964844
# last losses: [7.780949592590332, 0.1353129893541336, 2.0625815391540527]
# epoch 89|0; total loss:9.896100997924805
# last losses: [7.696161270141602, 0.13543887436389923, 2.0645012855529785]
# epoch 90|0; total loss:9.81486701965332
# last losses: [7.6146440505981445, 0.13470959663391113, 2.0655136108398438]
# epoch 91|0; total loss:9.73904800415039
# last losses: [7.538263320922852, 0.13413453102111816, 2.066650629043579]
# epoch 92|0; total loss:9.663965225219727
# last losses: [7.4596757888793945, 0.13437777757644653, 2.069911479949951]
# epoch 93|0; total loss:9.59176254272461
# last losses: [7.387818813323975, 0.1338733732700348, 2.070070266723633]
# epoch 94|0; total loss:9.517927169799805
# last losses: [7.31644344329834, 0.13278520107269287, 2.068697929382324]
# epoch 95|0; total loss:9.445629119873047
# last losses: [7.246676445007324, 0.13151302933692932, 2.0674400329589844]
# epoch 96|0; total loss:9.37339973449707
# last losses: [7.173731803894043, 0.13130736351013184, 2.0683608055114746]
# epoch 97|0; total loss:9.303377151489258
# last losses: [7.100902080535889, 0.1315622478723526, 2.070913314819336]
# epoch 98|0; total loss:9.232288360595703
# last losses: [7.031991004943848, 0.1306867152452469, 2.069611072540283]
# epoch 99|0; total loss:9.167060852050781
# last losses: [6.971341133117676, 0.12975218892097473, 2.065967082977295]
# Finished Training

# %%
with torch.no_grad():
    x_batch = x[None]
    y_pred = net(x_batch)
    y_pred_objs = net(x_batch, return_objects=True)

# %%
y[:5]
# Out:
# tensor([[127.1367,  69.8900, 251.9831, 138.2520,   0.0000,   1.0000],
#         [ 98.6739, 172.1500, 194.7458, 117.5960,   0.0000,   1.0000],
#         [ 14.8654, 218.2620,  29.0593,  60.0600,   0.0000,   1.0000],
#         [  0.0000,   0.0000,   0.0000,   0.0000,   0.0000,   0.0000],
#         [  0.0000,   0.0000,   0.0000,   0.0000,   0.0000,   0.0000]])

# %%
y_pred_objs[0, :10]
# Out:
# tensor([[9.8108e+01, 1.7348e+02, 1.4631e+01, 1.2056e+01, 0.0000e+00, 4.3220e-01],
#         [1.5127e+01, 2.1850e+02, 2.4175e+01, 2.0039e+01, 0.0000e+00, 3.7705e-01],
#         [1.7572e+02, 1.4963e+02, 6.2964e+01, 5.3370e+01, 0.0000e+00, 1.6493e-01],
#         [1.4382e+02, 1.4948e+02, 7.6939e+01, 6.5288e+01, 0.0000e+00, 1.1867e-01],
#         [1.2741e+02, 1.7244e+02, 8.4431e+01, 7.1719e+01, 0.0000e+00, 1.1313e-01],
#         [2.0892e+02, 1.4845e+02, 9.0328e+01, 7.6425e+01, 0.0000e+00, 1.0452e-01],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00]])
